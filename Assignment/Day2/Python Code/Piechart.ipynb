# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_excel("/media/abhishek/589E61B39E618A782/C-DAC Document/Advanced Analytics//Day2/Data_Files New/Census Education Data.xlsx",skiprows=17,nrows=6,usecols="A,B")
print(df)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
marital_status = df[df.columns[0]].tolist()
counts = df[df.columns[1]].tolist()
ax.pie(counts, labels = marital_status,autopct='%1.2f%%')
ax.set_title('Marital Status')
plt.show()
# Out:
#             Marital Status  Unnamed: 1
# 0            Never Married     4120320
# 1  Married, spouse present    15516160
# 2   Married, spouse absent     1847880
# 3                Separated     1188090
# 4                  Widowed     5145683
# 5                 Divorced     2968680
# /home/abhishek/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
